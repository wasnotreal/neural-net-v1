# %%
import pandas as pd

df = pd.read_parquet('../data/Benign-Monday-no-metadata.parquet')
df.head()
df.columns
df.dtypes
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       2
#       3 df = pd.read_parquet('../data/Benign-Monday-no-metadata.parquet')
#       4 df.head()
#       5 df.columns
# ----> 6 df.types
#       7 df.isnull().sum()
#
# File ~/Desktop/NEURAL_NET_V1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'
